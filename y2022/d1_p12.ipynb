# %%
# import io
# test_in = """1000
# 2000
# 3000

# 4000

# 5000
# 6000

# 7000
# 8000
# 9000

# 10000"""
# IN = io.StringIO(test_in)
IN = open("d1_in.txt")

with IN as f:
    lines = [
        [int(x) for x in line.split("\n")]
        for line in f.read().split("\n\n")
    ]

# %% [markdown]
# Part 1

# %%
max(sum(n) for n in lines)

# %% [markdown]
# Part 2

# %%
sum(sorted([sum(n) for n in lines], reverse=True)[:3])
