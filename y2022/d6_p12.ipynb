# %%
# import io
# test_in = "zcfzfwzzqfrljwzlrfnpqdbhtmscgvjw"
# test_in = "nznrnfrfntjfmvfwmzdfjlvtqnbhcprsg"
# IN = io.StringIO(test_in)
IN = open("d6_in.txt")

with IN as f:
    text = f.read()

# %% [markdown]
# Part 1

# %%
place = 0
for i, c in enumerate(text[:-3]):
    window = text[i:i+4]
    if len(set(window)) == 4:
        place= i+4
        break
place

# %% [markdown]
# Part 2

# %%
place = 0
for i, c in enumerate(text[:-13]):
    window = text[i:i+14]
    if len(set(window)) == 14:
        place= i+14
        break
place
